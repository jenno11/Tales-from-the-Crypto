# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/damienjennings/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    btc = pd.DataFrame(bitcoin_sentiments)

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    eth = pd.DataFrame(ethereum_sentiments)

# %%
# Describe the Bitcoin Sentiment
btc.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.120895    0.062540    0.029890    0.907560
# std      0.336729    0.057563    0.048198    0.075567
# min     -0.757900    0.000000    0.000000    0.708000
# 25%      0.000000    0.000000    0.000000    0.843750
# 50%      0.077200    0.052500    0.000000    0.918500
# 75%      0.340000    0.099000    0.054250    0.959250
# max      0.811600    0.213000    0.208000    1.000000

# %%
# Describe the Ethereum Sentiment
eth.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.142803    0.067400    0.030330    0.902280
# std      0.360029    0.070222    0.051283    0.084907
# min     -0.893400    0.000000    0.000000    0.688000
# 25%      0.000000    0.000000    0.000000    0.842000
# 50%      0.025800    0.057000    0.000000    0.910500
# 75%      0.421500    0.100000    0.065000    1.000000
# max      0.941300    0.308000    0.312000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Between the two coins, Ethereum has the higher mean positive score.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the highest max compound score of 0.844200 compared to Bitcoin 0.811600
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the highest max positive score in the comparison

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = stopwords.words("english")
sw.append("'/'")
sw.append("'\'")
sw.append("'s")
sw.append('char')
sw.append('chars')
sw.append('…')
sw.append('seen')

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    ## Kept getting an errow with the below code so i left it out.
    ### words = list(filter(lambda t: t not in punctuation, words))
   
    # Create a tokenized list of the words
    words = word_tokenize(text)
    
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the stop words
    words = list(filter(lambda t: t.lower() not in sw, words))
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc["tokens"] = btc.text.apply(tokenizer)
btc.head()
# Out:
#                                                 text        date  compound  \
# 0  You won't have to stick to Bitcoin if you're d...  2021-09-16    0.5574
# 1  PayPal will now allow users outside the U.S. t...  2021-08-23    0.4215
# 2  A recently-installed Bitcoin ATM.\r\n\n \n\n A...  2021-09-07    0.1779
# 3  The government of El Salvador purchased at lea...  2021-09-07    0.1280
# 4  PayPal is bringing the ability to buy, hold an...  2021-08-23    0.6908
#
#    positive  negative  neutral  \
# 0     0.127     0.036    0.838
# 1     0.098     0.000    0.902
# 2     0.052     0.000    0.948
# 3     0.046     0.000    0.954
# 4     0.161     0.000    0.839
#
#                                               tokens
# 0  [You, wo, n't, have, to, stick, to, Bitcoin, i...
# 1  [PayPal, will, now, allow, user, outside, the,...
# 2  [A, recently-installed, Bitcoin, ATM, ., As, o...
# 3  [The, government, of, El, Salvador, purchased,...
# 4  [PayPal, is, bringing, the, ability, to, buy, ...

# %%
# Create a new tokens column for Ethereum
eth["tokens"] = eth.text.apply(tokenizer)
eth.head()
# Out:
#                                                 text        date  compound  \
# 0  As the broader crypto world enjoys a late summ...  2021-08-31    0.7351
# 1  You won't have to stick to Bitcoin if you're d...  2021-09-16    0.5574
# 2  PayPal will now allow users outside the U.S. t...  2021-08-23    0.4215
# 3  OpenSea isn't wasting much time after its head...  2021-09-16    0.2865
# 4  PayPal is bringing the ability to buy, hold an...  2021-08-23    0.6908
#
#    positive  negative  neutral  \
# 0     0.167     0.000    0.833
# 1     0.127     0.036    0.838
# 2     0.098     0.000    0.902
# 3     0.180     0.126    0.694
# 4     0.161     0.000    0.839
#
#                                               tokens
# 0  [As, the, broader, crypto, world, enjoys, a, l...
# 1  [You, wo, n't, have, to, stick, to, Bitcoin, i...
# 2  [PayPal, will, now, allow, user, outside, the,...
# 3  [OpenSea, is, n't, wasting, much, time, after,...
# 4  [PayPal, is, bringing, the, ability, to, buy, ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
Counter(ngrams(tokenizer(btc.text.str.cat()), n=2)).most_common(50)
# Out:
# [(('char', ']'), 96),
#  (('El', 'Salvador'), 33),
#  (('(', 'Reuters'), 33),
#  (('Reuters', ')'), 33),
#  ((')', '-'), 31),
#  (('…', '['), 25),
#  ((',', '2021'), 24),
#  ((']', 'A'), 21),
#  (('legal', 'tender'), 21),
#  (('in', 'the'), 19),
#  (('2021', '.'), 19),
#  (('Bitcoin', 'is'), 17),
#  (('a', 'legal'), 16),
#  (('for', 'the'), 13),
#  (('.', 'The'), 13),
#  (('in', 'this'), 13),
#  (('this', 'illustration'), 13),
#  (('.', 'REUTERS/Dado'), 13),
#  (('of', 'bitcoin'), 13),
#  ((',', 'Sept'), 13),
#  (('is', 'seen'), 12),
#  (('illustration', 'taken'), 12),
#  (('6', ','), 12),
#  (('bitcoin', 'a'), 11),
#  (('of', 'cryptocurrency'), 11),
#  (('the', 'first'), 10),
#  ((',', 'El'), 10),
#  (('SALVADOR', ','), 10),
#  (('of', 'the'), 9),
#  (('Salvador', ','), 9),
#  (('representation', 'of'), 9),
#  (('cryptocurrency', 'Bitcoin'), 9),
#  (('seen', 'in'), 9),
#  (('taken', 'August'), 9),
#  (('August', '6'), 9),
#  (('A', 'representation'), 8),
#  (('-', 'El'), 8),
#  (('SAN', 'SALVADOR'), 8),
#  (('a', 'a'), 7),
#  (('on', 'Tuesday'), 7),
#  ((']', 'By'), 7),
#  ((',', 'and'), 7),
#  (('the', 'cryptocurrency'), 7),
#  ((']', 'Bitcoin'), 7),
#  (('to', 'a'), 7),
#  (('tender', ','), 7),
#  ((',', 'a'), 7),
#  ((',', 'Aug'), 7),
#  (('adoption', 'of'), 7),
#  (('Central', 'American'), 6)]

# %%
# Generate the Ethereum N-grams where N=2
Counter(ngrams(tokenizer(eth.text.str.cat()), n=2)).most_common(50)
# Out:
# [(('char', ']'), 98),
#  (('…', '['), 27),
#  (('(', 'Reuters'), 19),
#  (('Reuters', ')'), 19),
#  ((')', '-'), 18),
#  ((',', '2021'), 15),
#  ((',', 'the'), 14),
#  (('in', 'this'), 12),
#  (('this', 'illustration'), 12),
#  (('.', 'REUTERS/Dado'), 12),
#  ((',', 'and'), 12),
#  (('of', 'the'), 11),
#  (('illustration', 'taken'), 11),
#  (('2021', '.'), 11),
#  (('in', 'the'), 10),
#  ((']', 'A'), 10),
#  (('Ethereum', ','), 9),
#  (('for', 'the'), 9),
#  (('the', 'first'), 9),
#  ((',', 'a'), 9),
#  (('YORK', ','), 9),
#  ((',', 'Sept'), 9),
#  (('.', 'The'), 8),
#  (('Bitcoin', ','), 8),
#  ((',', 'Litecoin'), 7),
#  (('of', 'cryptocurrency'), 7),
#  (('NEW', 'YORK'), 7),
#  (('-', 'The'), 7),
#  (('placed', 'on'), 7),
#  ((',', 'Ethereum'), 7),
#  (('first', 'time'), 6),
#  (('to', 'a'), 6),
#  (('Monday', ','), 6),
#  (('is', 'seen'), 6),
#  (('the', 'past'), 6),
#  (('’', 's'), 6),
#  ((']', 'The'), 6),
#  (('Representations', 'of'), 6),
#  (('of', 'cryptocurrencies'), 6),
#  (('cryptocurrencies', 'Bitcoin'), 6),
#  ((',', 'DogeCoin'), 6),
#  (('DogeCoin', ','), 6),
#  ((',', 'Ripple'), 6),
#  (('Ripple', ','), 6),
#  (('Litecoin', 'are'), 6),
#  (('are', 'placed'), 6),
#  (('on', 'PC'), 6),
#  (('PC', 'motherboard'), 6),
#  (('motherboard', 'in'), 6),
#  (('June', '29'), 6)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_tokens = tokenizer(btc.text.str.cat())
token_count(btc_tokens, N=10)
# Out:
# [(',', 199),
#  ('the', 120),
#  ('a', 117),
#  ('[', 97),
#  (']', 97),
#  ('char', 96),
#  ('of', 80),
#  ('to', 78),
#  ('.', 74),
#  ('in', 74)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_tokens = tokenizer(eth.text.str.cat())
token_count(eth_tokens, N=10)
# Out:
# [(',', 212),
#  ('the', 123),
#  ('[', 99),
#  (']', 99),
#  ('char', 98),
#  ('a', 83),
#  ('.', 79),
#  ('of', 71),
#  ('to', 65),
#  ('in', 50)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wordcloud = WordCloud(colormap="coolwarm").generate(btc.text.str.cat())
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 40, "fontweight": "bold"}
plt.title("Bitcoin Word Cloud", fontdict=fontdict)
plt.show()

# %%
# Generate the Ethereum word cloud
wordcloud = WordCloud(colormap="bwr").generate(eth.text.str.cat())
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 40, "fontweight": "bold"}
plt.title("Ethereum Word Cloud", fontdict=fontdict)
plt.show()

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = btc.text.str.cat()
btc_text
# Out:
# 'You won\'t have to stick to Bitcoin if you\'re determined to pay for your movie ticket with cryptocurrency. AMC chief Adam Aron has revealed his theater chain will also accept Ethereum, Litecoin and Bi… [+1198 chars]PayPal will now allow users outside the U.S. to buy, hold and sell cryptocurrency for the first time. The company announced today the launch of a new service that will allow customers in the U.K. to … [+4420 chars]A recently-installed Bitcoin ATM.\r\n\n \n\n As of today, Bitcoin is an official currency of El Salvador alongside the US dollar, after the Central American country became the first to adopt the cryptocur… [+2716 chars]The government of El Salvador purchased at least 200 bitcoin recently, ahead of the country officially recognizing bitcoin as a form of legal currency on Tuesday. The purchase brings the governments … [+3142 chars]Retailers are increasingly accepting cryptocurrency for physical items, but did you know\xa0you can spend crypto on ephemeral experiences like travel too? As more cryptocurrency holders indicate a willi… [+2783 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of a year after it launched in the US. In a statement, the company said tha… [+850 chars]image captionProtesters held signs reading "no to Bitcoin"\r\nThousands of protesters have taken to the streets in El Salvador, angry at the introduction of Bitcoin as its legal tender.\r\nPresident Nayi… [+1352 chars]By Joe TidyCyber reporter \r\nTaxi driver Chris is obsessively checking his phone for updates.\r\n"I\'m set to lose almost 2,500 euros (£2,100) worth of cryptocurrency coins," he says.\r\nChris describes hi… [+6584 chars]New York (CNN Business)It\'s a volatile day for bitcoin, which briefly fell by about 10% Tuesday below the $43,000 mark.\r\nThe drop comes after El Salvador made good on a plan announced in June and ado… [+1279 chars]8. Were just days into September, and its time to start thinking about your spring garden.\r\nRather than following the common practice of planting and transplanting in spring, Rebecca McMackin, the di… [+494 chars]A representation of cryptocurrency Bitcoin is seen in this illustration taken August 6, 2021. REUTERS/Dado Ruvic/Illustration/File Photo/File Photo/File Photo/File PhotoSept 7 (Reuters) - Fintech Bit… [+1978 chars]PayPal is to allow users in the UK to buy, hold and sell cryptocurrencies through the payment platform for the first time.\r\nThe firm said it would allow customers to choose from four types of cryptoc… [+3160 chars]T-Mobile will offer two years of free identity theft protection services after hackers stole data on roughly 49 million customers and potential customers, according to a statement from the mobile car… [+2971 chars]A representation of cryptocurrency Bitcoin is seen in this illustration taken August 6, 2021. REUTERS/Dado Ruvic/Illustration/File PhotoSept 15 (Reuters) - AMC Entertainment (AMC.N) CEO Adam Aron sai… [+596 chars]Posted \r\nEl Zonte, El Salvador, home to \'Bitcoin Beach,\' is looking to ride the cryptocurrency wave as bitcoin becomes legal tender in the Central American country. Conway G. Gittens reports.Aug 27 (Reuters) - The first cryptocurrency ATM in Honduras opened this week as bitcoin backers sought to spur demand for virtual assets after neighboring El Salvador became the first country to esta… [+1733 chars]Aug 27 (Reuters) - The first cryptocurrency ATM in Honduras opened this week as bitcoin backers sought to spur demand for virtual assets after neighboring El Salvador became the first country to esta… [+1669 chars]Posted \r\nEl Zonte, El Salvador, home to \'Bitcoin Beach,\' is looking to ride the cryptocurrency wave as bitcoin becomes legal tender in the Central American country. Conway G. Gittens reports.Twitter\'s latest beta update introduces support for providing content creators with Bitcoin tips using the "Tip Jar" feature that Twitter introduced earlier th ...

# %%
# Run the NER processor on all of the text
doc = nlp(btc_text)

# Add a title to the document
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style="ent", jupyter="true")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">You won't have to stick to Bitcoin if you're determined to pay for your movie ticket with cryptocurrency.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chief
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Aron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has revealed his theater chain will also accept
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Litecoin and Bi… [+1198 chars]PayPal will now allow users outside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to buy, hold and sell cryptocurrency for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time. The company announced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the launch of a new service that will allow customers in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to … [+4420 chars]A recently-installed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin ATM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br> As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Bitcoin is an official currency of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar, after the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  country became the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  to adopt the cryptocur… [+2716 chars]The government of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  purchased
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least 200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoin recently, ahead of the country officially recognizing bitcoin as a form of legal currency on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The purchase brings the governments … [+3142 chars]Retailers are increasingly accepting cryptocurrency for physical items, but did you know you can spend crypto on ephemeral experiences like travel too? As more cryptocurrency holders indicate a willi… [+2783 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after it launched in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of protesters have taken to the streets in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nayi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+1352 chars]By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark cla

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# AMC ORG
# Adam Aron PERSON
# Ethereum PERSON
# U.S. GPE
# first ORDINAL
# today DATE
# U.K. GPE
# Bitcoin ATM ORG
# today DATE
# El Salvador GPE
# US GPE
# Central American NORP
# first ORDINAL
# El Salvador GPE
# at least 200 CARDINAL
# Tuesday DATE
# a year DATE
# US GPE
# Thousands CARDINAL
# El Salvador GPE
# Nayi PERSON
# Joe PERSON
# TidyCyber reporter MONEY
# Chris PERSON
# almost 2,500 CARDINAL
# 2,100 MONEY
# Chris PERSON
# chars]New York GPE
# CNN ORG
# a volatile day DATE
# about 10% PERCENT
# Tuesday DATE
# $43,000 mark MONEY
# El Salvador GPE
# June DATE
# chars]8 ORG
# just days DATE
# September DATE
# spring DATE
# Rebecca McMackin PERSON
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo/File Photo/File Photo/File PhotoSept 7 ORG
# Reuters ORG
# UK GPE
# first ORDINAL
# four CARDINAL
# chars]T-Mobile ORG
# two years DATE
# roughly 49 million CARDINAL
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File ORG
# 15 CARDINAL
# Reuters ORG
# Adam Aron PERSON
# El Zonte GPE
# El Salvador GPE
# Bitcoin Beach GPE
# Central American NORP
# Conway G. Gittens PERSON
# 27 CARDINAL
# Reuters ORG
# first ORDINAL
# ATM ORG
# Honduras GPE
# this week DATE
# El Salvador GPE
# first ORDINAL
# 27 CARDINAL
# Reuters ORG
# first ORDINAL
# ATM ORG
# Honduras GPE
# this week DATE
# El Salvador GPE
# first ORDINAL
# El Zonte GPE
# El Salvador GPE
# Bitcoin Beach GPE
# Central American NORP
# Conway G. Gittens PERSON
# Twitter PERSON
# Tip Jar WORK_OF_ART
# Twitter PERSON
# earlier this year DATE
# as much as 17 CARDINAL
# a month DATE
# El Salvadors NORP
# as low as US$43,050 MONEY
# New York Tuesda GPE
# +4328 PERSON
# as much as 17 CARDINAL
# US$43,050
#  MONEY
# San Salvador GPE
# Sept. 7 DATE
# 2021.Photo CARDINAL
# Ma PERSON
# first ORDINAL
# $311 billion MONEY
# Q2 2021 DATE
# Insider Intellige PERSON
# AAPL ORG
# iPhones ORG
# next week DATE
# Tuesday DATE
# California Streaming WORK_OF_ART
# +492 ORG
# Reuters ORG
# Sept 5 DATE
# Reuters ORG
# 0.49% PERCENT
# 50,188.4 MONEY
# 1004 DATE
# Sunday DATE
# 245.24 MONEY
# 81% PERCENT
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Reuters ORG
# 0.49% PERCENT
# 50,188.4 MONEY
# 1004 DATE
# Sunday DATE
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationAug PERSON
# 20 CARDINAL
# Reuters ORG
# 5.01 % PERCENT
# 49,106.4 MONEY
# 22:04 GMT TIME
# Friday DATE
# 20, 2021 DATE
# PennyStocksBitcoin Price Surge Helped Boost ORG
# Bitcoin, Dogecoin ORG
# Ethereum GPE
# T-Mobile ORG
# Roughly 47.8 million CARDINAL
# El Zonte Beach GPE
# Chiltiupan GPE
# El Salvador GPE
# June 10, 2021 DATE
# June 10, 2021 DATE
# REUTERS ORG
# Jose CabezasEL ZONTE PERSON
# El Salvador GPE
# Sept 7 DATE
# Reuters ORG
# Sevilla Barber Shop ORG
# Santa Tecla GPE
# El Salvador GPE
# September 6, 2021 DATE
# REUTERS ORG
# Jose PERSON
# Sept 7 DATE
# Reuters ORG
# El Salvador GPE
# Reuters ORG
# El Salvador GPE
# Tuesday DATE
# its first day DATE
# 10,000 CARDINAL
# 10,000 CARDINAL
# 41 MONEY
# Twitter PERSON
# Twitter al PERSON
# Punta Roca Beach FAC
# La Libertad GPE
# El Salvador GPE
# April 25, 2021 DATE
# REUTERS ORG
# Jose PERSON
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo/File Photo/File Photo/File PhotoLONDON ORG
# Sept 16 DATE
# Reuters ORG
# El Salvadors GPE
# Salvadoran NORP
# 23 CARDINAL
# Reuters ORG
# 50,000 MONEY
# Monday DATE
# first ORDINAL
# May DATE
# months-long DATE
# 50 MONEY
# Reuters ORG
# MEXICO CITY PERSON
# Sept 9 DATE
# Reuters ORG
# Mexicos PRODUCT
# Thursday DATE
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration NEW YORK ORG
# Sep ORG
# Stacey Coon PERSON
# Anastasia Sultzer PERSON
# Nanu Berk PERSON
# 2021 DATE
# Marco Bello PERSON
# Getty Images ORG
# Cathie Wood's PERSON
# Ark Investment Management ORG
# 6, 2021 DATE
# Spanish NORP
# AI ORG
# Alto Nivel
# p&gt ORG
# 24, 2021 DATE
# Entrepreneur ORG
# El Salvador’s GPE
# Bitcoin  GPE
# chars]El Salvador GPE
# first ORDINAL
# Tuesday DATE
# chars]NEW YORK GPE
# Reuters ORG
# Wednesday DATE
# a day DATE
# El Salvador GPE
# U.S. GPE
# Coinbase Glob PERSON
# nearly 36% PERCENT
# Americans NORP
# YouGov ORG
# some 28% PERCENT
# 24 CARDINAL
# Reuters ORG
# Tuesday DATE
# El Salvador's GPE
# Salvadorans NORP
# millions of dollars MONEY
# Libby PERSON
# Mario Gomez PERSON
# San Salvador GPE
# El Salvador GPE
# September 1, 2021 DATE
# REUTERS ORG
# El Salvador's GPE
# a big day DATE
# El Salvador GPE
# Boeing ORG
# the week to September 10 DATE
# Ilan Rubens PERSON
# El Salvador's GPE
# Tuesday DATE
# German NORP
# DAX ORG
# Frankfurt GPE
# Germany GPE
# June 24, 2016 DATE
# REUTERS/Staff/Rem ORG
# Each month DATE
# Salvadoran NORP
# Julio Ramirez PERSON
# two CARDINAL
# the United States GPE
# a few dollars MONEY
# 2009 DATE
# December 8, 2017 DATE
# REUTERS ORG
# Dado Ruvic/ PERSON
# Sept 8 DATE
# Reuters ORG
# Sevilla Barber Shop ORG
# Santa Tecla GPE
# El Salvador GPE
# September 6, 2021 DATE
# REUTERS ORG
# Jose PERSON
# Sept 7 DATE
# Reuters ORG
# Jackson/Reuters ORG
# Crypto PERSON
# Mike Novogratz PERSON
# Dado Ruvic PERSON
# Reuters ORG
# as much as CARDINAL
# 4.4% PERCENT
# Thursday DATE
# 50,000 MONEY
# the past year DATE
# 2009 DATE
# the last few years DATE
# 23, 2021 DATE
# months-long DATE
# above $50,000 MONEY
# Sunday DATE
# first ORDINAL
# mid-May. DATE
# chars]This week DATE
# El Salvador GPE
# first ORDINAL
# this week DATE
# just three months DATE
# first ORDINAL
# the Securities and Exchange Commission ORG
# SEC ORG
# Fidelity Investments ORG
# 24 CARDINAL
# Reuters ORG
# Central American NORP
# El Salvadors GPE
# Sept 7 DATE
# Reuters ORG
# El Salvador GPE
# Tuesday DATE
# first ORDINAL
# India GPE
# AI GPE
# one CARDINAL
# India GPE
# AI GPE
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo/File PhotoSAN SALVADOR ORG
# Aug 31 DATE
# Reuters ORG
# El Salvador's GPE
# Congr ORG
# Kelly/Reuters ORG
# Katie Stockton PERSON
# Reuters ORG
# NEW YORK GPE
# Sept 10 DATE
# Reuters ORG
# El Salvador GPE
# weekly DATE
# almost a year DATE
# 25 CARDINAL
# Reuters ORG
# September DATE
# Honduran NORP
# Guatemalan ORG
# Honduran NORP
# 24 CARDINAL
# Reuters ORG
# Central American NORP
# July 14, 2021 DATE
# REUTERS ORG
# Dado Ruvic/ PERSON
# 23 CARDINAL
# Reuters ORG
# Reuters ORG
# SAN SALVADOR GPE
# Sept 1 DATE
# Reuters ORG
# Salvadoran NORP
# Wednesday DATE
# Nayib Bukeles PERSON
# Reuters ORG
# Reuters ORG
# Wednesday DATE
# a day DATE
# 2-1/2 months DATE
# El Salvadors GPE
# chars]NEW YORK GPE
# Sept 15 DATE
# Reuters ORG
# Steven Cohen PERSON
# Ray Dalio PERSON
# this week DATE
# Reuters ORG
# Reuters ORG
# El Salvadors Court of Accounts ORG
# Kelly/Reuters ORG
# Tuesday DATE
# El Salvador GPE
# about $52,000 MONEY
# 24 CARDINAL
# Reuters ORG
# Central American NORP
# El Salvador's GPE
# Exclusive Bitcoin register" WORK_OF_ART
# Starbucks ORG
# San Salvador GPE
# El Salvador GPE
# September 7, 2021 DATE
# REUTERS ORG
# Jose CabezasTOKYO PERSON
# Se PERSON
# Australia GPE
# Macquarie Group Ltd ORG
# Sydney GPE
# Australia GPE
# Oct. 28, 2016 DATE
# REUTERS ORG
# David Gray PERSON
# chars]El Salvador GPE
# first ORDINAL
# 400 CARDINAL
# Tuesday DATE
# Nayib Bukele PERSON
# Sullivan PERSON
# Getty Images ORG
# CoinDesk PRODUCT
# two CARDINAL
# one CARDINAL
# Fidelity Digital ORG
# SEC ORG
# Sept 8 DATE
# Reuters ORG
# El Salvador's GPE
# Nayib Bukele PERSON
# Wednesday DATE
# Binance PERSON
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Sept 13 DATE
# Reuters ORG
# next year DATE
# CoinTelegraph ORG
# KOHSAR ORG
# AFP ORG
# Mike Novogratz PERSON
# Charles Hoskinson PERSON
# Afghani ORG
# Dorsey PERSON
# TBD ORG
# 2021 DATE
# Chris McGrath PERSON
# one-quarter DATE
# Americans NORP
# YouGov ORG
# U.S. Securities and Exchange Commission ORG
# SEC ORG
# SEC ORG
# Sept 8 DATE
# Getty Images PERSON
# Elon Musk PERSON
# Sprich/Reuters ORG
# Ray Dalio PERSON
# Bridgewater Associates ORG
# CNBC ORG
# Dorsey PERSON
# TBD ORG
# Michael Saylor PERSON
# Joe Raedle PERSON
# about $5.1 MONEY
# 18, 2021 DATE
# Entrepreneur ORG
# Earlier this year DATE
# Grayscale Bitcoin Trust ORG
# Yuriko Nakao PERSON
# Three CARDINAL
# Grayscale Investments ORG
# 31, DATE
# 2021 DATE
# Spanish NORP
# AI ORG
# John Paulson PERSON
# U.S. GPE
# more than a decade ago DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = eth.text.str.cat()
eth_text
# Out:
# 'As the broader crypto world enjoys a late summer surge in enthusiasm, more and more blockchain developers who have taken the plunge are bumping into the blaring scaling issues faced by decentralized … [+3414 chars]You won\'t have to stick to Bitcoin if you\'re determined to pay for your movie ticket with cryptocurrency. AMC chief Adam Aron has revealed his theater chain will also accept Ethereum, Litecoin and Bi… [+1198 chars]PayPal will now allow users outside the U.S. to buy, hold and sell cryptocurrency for the first time. The company announced today the launch of a new service that will allow customers in the U.K. to … [+4420 chars]OpenSea isn\'t wasting much time after its head of product was accused of exploiting insider information to turn a profit on non-fungible tokens. The marketplace has asked for and accepted Nate Chasta… [+924 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of a year after it launched in the US. In a statement, the company said tha… [+850 chars]One of the most unusual cryptocurrency heists in recent memory has come to a close. On Monday, Poly Network, a decentralized finance platform that saw a hacker named Mr. White Hat exploit a vulnerabi… [+1513 chars]Vitalik Buterin\r\nVitalik Buterin dreamed up ethereum in 2013.\r\nGetty Images/John Phillips\r\nVitalik Buterin has compared the eight founders of the ethereum blockchain to JRR Tolkien\'s close-knit "fell… [+5139 chars]Cardano ada\r\nSOPA images\r\nThe cardano network took a step closer this past weekend to competing more fiercely with the larger ethereum network, after a key upgrade meant it could host decentralized f… [+2036 chars]Sen. Elizabeth Warren.\r\nGREG NASH/POOL/AFP via Getty Images\r\nSen. Elizabeth Warren has criticized the high fees on ethereum\'s network during heightened trading volatility, arguing they could substant… [+2416 chars]Justin Sullivan/Getty Images\r\nCitigroup is actively recruiting traders to begin working with bitcoin futures, according to a new CoinDesk report.\r\nThe report, citing two sources including one within … [+1597 chars]LONDON, Aug 25 (Reuters) - Tags for identifying bitcoin, ethereum and other crypto assets will be launched in September in the latest sign of how the fast growing, unregulated market is adopting the … [+2613 chars]A representation of cryptocurrency Bitcoin is seen in this illustration taken August 6, 2021. REUTERS/Dado Ruvic/Illustration/File PhotoSept 15 (Reuters) - AMC Entertainment (AMC.N) CEO Adam Aron sai… [+596 chars]Solana\'s SOL token surged above $100 for the first time on Monday, with a recent mix of projects and interest from institutional investors propelling the altcoin up by more than 200% as August winds … [+1616 chars]PayPal\xa0launched its crypto services in the UKits first international crypto expansion, according to a press release.\r\nPayPal\'s total payment volume reached $311 billion in Q2 2021.\r\nInsider Intellige… [+2125 chars]Vitalik Buterin launched ethereum in 2015.\r\nJohn Phillips/Getty Images for TechCrunch\r\nEthereum cofounder Vitalik Buterin has been named on Time magazine\'s prestigious list of the world\'s 100 most in… [+1792 chars]Blockchain technology has emerged as a revolutionary force for change on the global stage over the past decade as Bitcoin has risen from being shadowy internet money used by criminals to an accepted … [+6744 chars]Editor’s note:Kyle Russell is the founder of Playbyte, a startup building an app that lets people make games on their phones.\r\nLast Friday, Dom Hofmann tweeted the launch of\xa0Loot, one of his new proj… [+7658 chars]Alexi Rosenfeld/Getty Images\r\nCrypto exchange FTX has started charging a $500 fee for people to mint their own non-fungible token on its newly launched native NFT marketplace, after being swamped wit… [+2973 chars]This Tuesday, the \'altcoin\' Solana (SOL) became the seventh cryptocurrency with the highest market capi ...

# %%
# Run the NER processor on all of the text
doc = nlp(eth_text)

# Add a title to the document
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style="ent", jupyter="true")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">As the broader crypto world enjoys a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  surge in enthusiasm, more and more blockchain developers who have taken the plunge are bumping into the blaring scaling issues faced by decentralized … [+3414 chars]You won't have to stick to Bitcoin if you're determined to pay for your movie ticket with cryptocurrency.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chief
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Aron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has revealed his theater chain will also accept
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Litecoin and Bi… [+1198 chars]PayPal will now allow users outside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to buy, hold and sell cryptocurrency for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time. The company announced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the launch of a new service that will allow customers in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to … [+4420 chars]OpenSea isn't wasting much time after its head of product was accused of exploiting insider information to turn a profit on non-fungible tokens. The marketplace has asked for and accepted
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nate Chasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +924
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after it launched in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In a statement, the company said tha… [+850 chars]One of the most unusual cryptocurrency heists in recent memory has come to a close. On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poly Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a decentralized finance platform that saw a hacker named Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     White
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Hat exploit a vulnerabi… [+1513 chars]Vitalik
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  dreamed up ethereum in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Phillips
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has compared the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-al

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# late summer DATE
# AMC ORG
# Adam Aron PERSON
# Ethereum PERSON
# U.S. GPE
# first ORDINAL
# today DATE
# U.K. GPE
# Nate Chasta PERSON
# +924 ORG
# a year DATE
# US GPE
# Monday DATE
# Poly Network ORG
# White PERSON
# Buterin GPE
# Vitalik Buterin PERSON
# 2013 DATE
# Getty Images PERSON
# John Phillips PERSON
# Vitalik Buterin PERSON
# eight CARDINAL
# this past weekend DATE
# Elizabeth Warren PERSON
# AFP ORG
# Getty Images ORG
# Elizabeth Warren PERSON
# Sullivan PERSON
# Getty Images
# Citigroup ORG
# CoinDesk PRODUCT
# two CARDINAL
# one CARDINAL
# 25 CARDINAL
# Reuters ORG
# September DATE
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File ORG
# 15 CARDINAL
# Reuters ORG
# Adam Aron PERSON
# above $100 MONEY
# first ORDINAL
# Monday DATE
# more than 200% PERCENT
# August DATE
# first ORDINAL
# $311 billion MONEY
# Q2 2021 DATE
# Insider Intellige PERSON
# 2015 DATE
# John Phillips PERSON
# Vitalik Buterin PERSON
# Time ORG
# 100 CARDINAL
# the past decade DATE
# Kyle Russell PERSON
# Playbyte ORG
# Last Friday DATE
# Dom Hofmann PERSON
# one CARDINAL
# Rosenfeld PERSON
# FTX ORG
# 500 MONEY
# NFT ORG
# Tuesday DATE
# Solana PERSON
# seventh ORDINAL
# Dogecoin ORG
# Elon Musk's PERSON
# Ethereum GPE
# Reuters ORG
# NEW YORK GPE
# Sept 3 DATE
# Reuters ORG
# second ORDINAL
# Friday DATE
# 4,000 MONEY
# first ORDINAL
# May 15 DATE
# 10,000 CARDINAL
# 10,000 CARDINAL
# 41 MONEY
# Chuck Mikolajczak PERSON
# NEW YORK GPE
# Sept 1 DATE
# Reuters ORG
# Monday DATE
# Poly Network ORG
# White Hat PERSON
# $610 million MONEY
# Hollywood GPE
# NFT ORG
# Larva Labs PERSON
# CryptoPunks PRODUCT
# United Talent Agency ORG
# UTA ORG
# Amazon ORG
# OpenSea ORG
# iOS GPE
# Android GPE
# 1.5 MONEY
# December 8, 2017 DATE
# REUTERS ORG
# Dado Ruvic/ PERSON
# Sept 8 DATE
# Reuters ORG
# Reuters ORG
# Sept 5 DATE
# Reuters ORG
# 0.49% PERCENT
# 50,188.4 MONEY
# 1004 DATE
# Sunday DATE
# 245.24 MONEY
# 81% PERCENT
# 27 CARDINAL
# Reuters ORG
# first ORDINAL
# ATM ORG
# Honduras GPE
# this week DATE
# El Salvador GPE
# first ORDINAL
# 27 CARDINAL
# Reuters ORG
# first ORDINAL
# ATM ORG
# Honduras GPE
# this week DATE
# El Salvador GPE
# first ORDINAL
# late Thursday DATE
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationAug PERSON
# 20 CARDINAL
# Reuters ORG
# 5.01 % PERCENT
# 49,106.4 MONEY
# 22:04 GMT TIME
# Friday DATE
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Reuters ORG
# 0.49% PERCENT
# 50,188.4 MONEY
# 1004 DATE
# Sunday DATE
# almost two weeks ago DATE
# Alex Castro PERSON
# The Verge WORK_OF_ART
# $600 million MONEY
# Poly Network ORG
# UK GPE
# first ORDINAL
# four CARDINAL
# Kardashian NORP
# June DATE
# NurPhoto PERSON
# UK GPE
# Kim Kardashian PERSON
# Getty Images PERSON
# Elon Musk PERSON
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File PhotoSep ORG
# Grayscale Bitcoin Trust ORG
# Yuriko Nakao PERSON
# Three CARDINAL
# Grayscale Investments ORG
# last week DATE
# 20% PERCENT
# CoinShares ORG
# American Express ORG
# Charles Hoskinson PERSON
# Charles Hoskinson PERSON
# Charles Hoskinson PERSON
# CNBC ORG
# Tuesday DATE
# second ORDINAL
# Dado Ruvic PERSON
# Reuters ORG
# More than $1 billion MONEY
# just six weeks DATE
# Lond ORG
# Reuters ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustrat PERSON
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration NEW YORK ORG
# Sep ORG
# this week DATE
# T-Mobile ORG
# at least 48 million CARDINAL
# Robinhood Markets Inc. ORG
# +1.66% PERCENT
# Robinhood ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File PhotoSEO ORG
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# 21 CARDINAL
# Reuters ORG
# 1-1/2 month DATE
# Binance PERSON
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Sept 13 DATE
# Reuters ORG
# the past 24 hours TIME
# Solana PERSON
# Solana PERSON
# almost 20% PERCENT
# the past day DATE
# Coinbase ORDINAL
# American Express ORG
# Finance Insider PERSON
# American Express ORG
# 23, 2021 DATE
# months-long DATE
# above $50,000 MONEY
# Sunday DATE
# first ORDINAL
# mid-May. DATE
# ADA ORG
# third ORDINAL
# 8% PERCENT
# the past 24 hours TIME
# Sunday DATE
# above $3,400 MONEY
# Tuesday DATE
# first ORDINAL
# May DATE
# Ethereum GPE
# 2 CARDINAL
# Arbitrum One ORG
# years DATE
# CryptoPunk 7610 PRODUCT
# one CARDINAL
# 3,840 CARDINAL
# around $150,000 MONEY
# last week DATE
# 2017 DATE
# Larva Labs PERSON
# 10,000 CARDINAL
# Alexander Lukashenko PERSON
# Dmitry Astakhov/Pool/AFP ORG
# Getty Images ORG
# Belarus GPE
# Alexander Lukashenko PERSON
# Powell PERSON
# the Federal Reserve ORG
# US GPE
# last week's DATE
# Monday DATE
# the Federal Reserve ORG
# Bankman-Fried ORG
# FTX ORG
# Lam Yik PERSON
# Bloomberg PERSON
# Getty Images
# FTX.US ORG
# American NORP
# FTX ORG
# Tuesday DATE
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# 13 CARDINAL
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Sept DATE
# 12-year-old DATE
# about £290,000 MONEY
# Benyamin Ahmeds PERSON
# Week DATE
# Last week DATE
# Bezos’s Blue Origin ORG
# NASA ORG
# This week DATE
# NFT ORG
# the Next Generation Internet EVENT
# EU ORG
# Horizon research &amp ORG
# HTTP ORG
# $2 trillion MONEY
# Nurphoto
# Cases ORG
# this year DATE
# Tuesd ORG
# April 2022 DATE
# AMC ORG
# Adam Aron PERSON
# Yuriko Nakao/Getty PERSON
# Su Zhu PERSON
# Osaka GPE
# Yukihito Taguchi-USA PERSON
# Naomi Osaka PERSON
# four CARDINAL
# Bloomberg ORG
# 23, 2021 DATE
# Monday DATE
# the United Kingdom GPE
# this week DATE
# 2021 DATE
# Spanish NORP
# AI ORG
# chars]The U.S. Securities and Exchange Commission ORG
# SEC ORG
# SEC ORG
# Sept 8 DATE
# 20, 2021 DATE
# PennyStocksBitcoin Price Surge Helped Boost ORG
# Bitcoin, Dogecoin ORG
# Ethereum GPE
# Mila Kunis PERSON
# Seth MacFarlane PERSON
# Chris Rock PERSON
# Jane Fonda PERSON
# Ashton Kutcher PERSON
# Ethereum PERSON
# Aug 31 DATE
# Reuters ORG
# more than three-weeks CARDINAL
# Tuesday DATE
# U.S. GPE
# later this week DATE
# Turkey GPE
# Reuters ORG
# Muhammad Ali PERSON
# Taliban ORG
# Afghanistan GPE
# DBS GPE
# Singapore GPE
# January 5, 2016 DATE
# REUTERS ORG
# Edgar Su/File Photo PERSON
# Sept 13 DATE
# Reuters ORG
# Singapore GPE
# DBS Group ORG
# chars]NEW YORK GPE
# Sept 2 DATE
# Reuters ORG
# Thursday DATE
# one-month DATE
# European Central Bank ORG
# Turkey GPE
# Aug 25 DATE
# Reuters ORG
# Muhammad Ali PERSON
# Taliban ORG
# Afghanistan GPE
# Sept 1 DATE
# Reuters ORG
# Wednesday DATE
# U.S. GPE
# chars]NEW YORK GPE
# Sept 3 DATE
# Reuters ORG
# a fourth straight day DATE
# Friday DATE
# U.S. GPE
# 20% PERCENT
# Monday DATE
# the Walmart Inc. ORG
# WMT ORG
# the past few months DATE
# GPU ORG
# German NORP
# 3D Center ORG
# GPU ORG
# Monday DATE
# NFT ORG
# this year DATE
# last night TIME
# Getty Images PERSON
# 2017 DATE
# Joe TidyCyber PERSON
# Chris PERSON
# almost 2,500 CARDINAL
# 2,100 MONEY
# Chris PERSON
# Blockchain Developer Bundle PERSON
# one CARDINAL
# Ethereum PERSON
# roughly 3.1%, 6% PERCENT
# 3.8% PERCENT
# 4:15 p.m. EDT TIME
# Wednesday DATE
# KOHSAR ORG
# AFP ORG
# Mike Novogratz PERSON
# Charles Hoskinson PERSON
# Afghani ORG
# The Fine Print ORG
# SEC ORG
# Congress ORG
# SEC ORG
# May. Bitcoin PERSON
# more than $50,000 MONEY
# Sept. 4 DATE
# 20% PERCENT
# a month ago DATE
# CoinDesk ORG
# matter.</li><li PRODUCT
# Bitcoins PERSON
# Financia PERSON
# chars]AMC Entertainment Holdings ORG
# Adam Aron PERSON
# Thursday DATE
# Aron PERSON
# first ORDINAL

# %% [markdown]
# ---
